# %%
from PIL import Image
import requests
from io import BytesIO

# %%
url = 'https://cdn.myanimelist.net/images/anime/1083/115046.jpg'

# %%
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x317>

# %%
df = pd.read_csv('data/anime.csv')

# %%
idx = df['English name'] == 'Unknown'
df.loc[idx, 'English name'] = df.loc[idx, 'Name']

# %%
(df['English name'] == 'Unknown').sum()
# Out:
# 0

# %%
df
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy_Bebop     8.78
# 1           5  Cowboy_Bebop__Tengoku_no_Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch_Hunter_Robin     7.27
# 4           8                   Bouken_Ou_Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu_Biji_Zhi_Qinling_Shen_Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi_no_Naku_Koro_ni_Sotsu  Unknown
# 17560   48491      Yama_no_Susume__Next_Summit  Unknown
# 17561   48492                    Scarlet_Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...
